# %%
install.packages("devtools")
devtools::install_github("sfsheath/cawd")
install.packages("sp")
# Out:
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)
# ...
# from URL https://api.github.com/repos/sfsheath/cawd/zipball/master
# Installing cawd
# '/usr/lib/R/bin/R' --no-site-file --no-environ --no-save --no-restore --quiet  \
#   CMD INSTALL '/tmp/RtmpT3wexE/devtools3948c2b0ff/sfsheath-cawd-928f175'  \
#   --library='/srv/rlibs' --install-tests
#
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)

# %%
library("sp")
library("cawd")
par(mai=c(0,0,0,0))
plot(awmc.roman.empire.200.sp)
# Out:
# plot without title

# %% [markdown]
# Ah yes, a nice map of the Roman Empire at 200 BCE. Very bounded by the Alps, it seems.

# %%
data()

# %%
library("sp")
library("cawd")
par(mai=c(0,0,0,0))
plot(darmc.roman.roads.major.sp)
# Out:
# plot without title

# %% [markdown]
# Now a map of the same(ish) area except where the roads are. Unless you are coming from Africa or Britannia, all roads do lead to Rome.

# %%
plot(beaver1)
# Out:
# plot without title

# %%
plot(beaver2)
# Out:
# plot without title

# %% [markdown]
# And just to keep it interesting, the heat difference between not one...but TWO beavers.
